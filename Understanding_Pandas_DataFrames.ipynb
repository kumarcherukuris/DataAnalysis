# %%
# Import the Libraries

import pandas as pd
import numpy as np

# %%
# Load the Data

df = pd.read_csv('C:\\Users\\user\\Workshop_Files\\BasicDataClearing_Ploting\\weather_data.csv')

# %%
# Print the data frame to view the Data
# head is a function that display based on the number that we pass
df.head()
# Out:
#           day  temperature  windspeed  event
# 0  01-01-2017         32.0        6.0   Rain
# 1  01-02-2017         35.0        7.0  Sunny
# 2  01-03-2017         28.0        2.0   Snow
# 3  01-04-2017         24.0        7.0   Snow
# 4  01-05-2017         32.0        4.0   Rain

# %%
# Lets get shape of the data frame which gives us number of rows and colums
df.shape
# Out:
# (20, 4)

# %%
# lets get columns list
df.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
# Lets get the information about the dataframe such as columns and their data types non-null details etc.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          20 non-null     object
#  1   temperature  17 non-null     float64
#  2   windspeed    19 non-null     float64
#  3   event        17 non-null     object
# dtypes: float64(2), object(2)
# memory usage: 772.0+ bytes

# %%
# Describe function gives us the mean/max/min/ std and other percentil details
df.describe()
# Out:
#        temperature  windspeed
# count    17.000000  19.000000
# mean     30.764706   5.789474
# std       7.335951   2.347077
# min      23.000000   2.000000
# 25%      23.000000   4.000000
# 50%      31.000000   7.000000
# 75%      33.000000   7.500000
# max      45.000000   9.000000

# %%
# Lets get the details for data types of each column
df.dtypes
# Out:
# day             object
# temperature    float64
# windspeed      float64
# event           object
# dtype: object

# %%
# Copy data frame
df1 =  df.copy(deep=False)

# %%
df1.head()
# Out:
#           day  temperature  windspeed  event
# 0  01-01-2017         32.0        6.0   Rain
# 1  01-02-2017         35.0        7.0  Sunny
# 2  01-03-2017         28.0        2.0   Snow
# 3  01-04-2017         24.0        7.0   Snow
# 4  01-05-2017         32.0        4.0   Rain

# %%
# Get the 'info axis' nothing but columns as keys
df.keys()
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
# Remove element from a data frame
df.drop(1)
# Out:
#            day  temperature  windspeed  event
# 0   01-01-2017         32.0        6.0   Rain
# 2   01-03-2017         28.0        2.0   Snow
# 3   01-04-2017         24.0        7.0   Snow
# 4   01-05-2017         32.0        4.0   Rain
# 5   01-06-2017          NaN        2.0  Sunny
# 6   01-07-2017         31.0        4.0   Snow
# 7   01-08-2017         32.0        7.0   Rain
# 8   01-09-2017         45.0        8.0    NaN
# 9   01-10-2017         23.0        4.0  Sunny
# 10  01-11-2017         23.0        8.0  Sunny
# 11  01-12-2017         42.0        9.0   Snow
# 12  01-01-2018          NaN        2.0   Rain
# 13  01-02-2018         23.0        4.0   Rain
# 14  01-03-2018         33.0        7.0  Sunny
# 15  01-04-2018         23.0        5.0   Snow
# 16  01-05-2018         43.0        7.0    NaN
# 17  01-06-2018         23.0        8.0   Rain
# 18  01-07-2018          NaN        NaN    NaN
# 19  01-08-2018         31.0        9.0   Snow

# %%
# Return the last n rows.
df1.tail(2)
# Out:
#            day  temperature  windspeed event
# 18  01-07-2018          NaN        NaN   NaN
# 19  01-08-2018         31.0        9.0  Snow

# %%
#Get item from object for given key (ex: DataFrame column).

df.get(['temperature', 'windspeed'])
# Out:
#     temperature  windspeed
# 0          32.0        6.0
# 1          35.0        7.0
# 2          28.0        2.0
# 3          24.0        7.0
# 4          32.0        4.0
# 5           NaN        2.0
# 6          31.0        4.0
# 7          32.0        7.0
# 8          45.0        8.0
# 9          23.0        4.0
# 10         23.0        8.0
# 11         42.0        9.0
# 12          NaN        2.0
# 13         23.0        4.0
# 14         33.0        7.0
# 15         23.0        5.0
# 16         43.0        7.0
# 17         23.0        8.0
# 18          NaN        NaN
# 19         31.0        9.0

# %%
# Count non-NA cells for each column or row.
df.count()
# Out:
# day            20
# temperature    17
# windspeed      19
# event          17
# dtype: int64

# %%
#DataFrame.isnull is an alias for DataFrame.isna.
df.isnull().sum()
# Out:
# day            0
# temperature    3
# windspeed      1
# event          3
# dtype: int64

# %% [markdown]
# # Missing data handling

# %%
#Remove missing values.

df.dropna()
# Out:
#            day  temperature  windspeed  event
# 0   01-01-2017         32.0        6.0   Rain
# 1   01-02-2017         35.0        7.0  Sunny
# 2   01-03-2017         28.0        2.0   Snow
# 3   01-04-2017         24.0        7.0   Snow
# 4   01-05-2017         32.0        4.0   Rain
# 6   01-07-2017         31.0        4.0   Snow
# 7   01-08-2017         32.0        7.0   Rain
# 9   01-10-2017         23.0        4.0  Sunny
# 10  01-11-2017         23.0        8.0  Sunny
# 11  01-12-2017         42.0        9.0   Snow
# 13  01-02-2018         23.0        4.0   Rain
# 14  01-03-2018         33.0        7.0  Sunny
# 15  01-04-2018         23.0        5.0   Snow
# 17  01-06-2018         23.0        8.0   Rain
# 19  01-08-2018         31.0        9.0   Snow

# %%
#Fill NA/NaN values using the specified method.
df.fillna(0).head()
# Out:
#           day  temperature  windspeed  event
# 0  01-01-2017         32.0        6.0   Rain
# 1  01-02-2017         35.0        7.0  Sunny
# 2  01-03-2017         28.0        2.0   Snow
# 3  01-04-2017         24.0        7.0   Snow
# 4  01-05-2017         32.0        4.0   Rain

# %%
df.head()
# Out:
#           day  temperature  windspeed  event
# 0  01-01-2017         32.0        6.0   Rain
# 1  01-02-2017         35.0        7.0  Sunny
# 2  01-03-2017         28.0        2.0   Snow
# 3  01-04-2017         24.0        7.0   Snow
# 4  01-05-2017         32.0        4.0   Rain

# %%
# Plot the temrature and windspeed  (BASIC plot)
#df.dropna()
#df = df.fillna(0)
plot = df.plot()

# %%
plot = df.plot(kind='bar')
